# %%
import pandas as pd

# %% [markdown]
# # Xử lý dữ liệu Facebook

# %%
df = pd.read_excel('C:\\Users\\Nguyen_Thanh_Vinh\\Downloads\\Dataset\\TikTok\\Origin\\Khaar_tiktok-scraper_2024-08-19_09-20-00-623.xlsx')
df
# Out:
#                                    authorMeta/avatar  authorMeta/bioLink  \
# 0  https://p16-sign-sg.tiktokcdn.com/aweme/720x72...                 NaN
# 1  https://p16-sign-sg.tiktokcdn.com/aweme/720x72...                 NaN
# 2  https://p16-sign-sg.tiktokcdn.com/aweme/720x72...                 NaN
#
#   authorMeta/commerceUserInfo/category  \
# 0               Clothing & Accessories
# 1               Clothing & Accessories
# 2               Clothing & Accessories
#
#    authorMeta/commerceUserInfo/categoryButton  \
# 0                                       False
# 1                                       False
# 2                                       False
#
#    authorMeta/commerceUserInfo/commerceUser  authorMeta/digg  authorMeta/fans  \
# 0                                      True                0                4
# 1                                      True                0                4
# 2                                      True                0                4
#
# ...

# %%
# # Facebook col
# col = ['facebookId', 'text', 'comments', 'likes', 'isVideo', 'media/0/__isMedia', 'media/1/__typename', 'media/2/__typename', 'media/3/__typename', 'media/4/__typename', 'media/5/__typename', 'viewsCount', 'timestamp', 'time', 'pageAdLibrary/is_business_page_active', 'media/0/playable_duration_in_ms', 'media/0/liveViewerCount', 'media/0/is_video_broadcast', 'media/0/is_spherical_enabled', 'media/0/is_spherical', 'media/0/is_soundbites_video', 'media/0/is_rss_podcast_video', 'media/0/is_podcast_video', 'media/0/is_ncsr', 'media/0/is_music_clip', 'media/0/is_live_streaming', 'media/0/is_live_audio_room_v2_broadcast', 'media/0/is_latency_sensitive_broadcast', 'media/0/is_gaming_video', 'media/0/is_clip', 'media/0/can_viewer_share']
# TikTok
col = ['id', 'authorMeta/digg', 'authorMeta/fans', 'authorMeta/region', 'collectCount', 'commentCount', 'createTime', 'createTimeISO', 'diggCount', 'isPinned', 'isSlideshow', 'playCount', 'shareCount', 'videoMeta/duration', 'videoMeta/format']
# Posts Instagram
# col = ['id', 'alt', 'caption', 'type', 'commentsCount', 'likesCount', 'isSponsored', 'videoDuration', 'videoPlayCount', 'videoViewCount', 'timestamp', \
#        'childPosts/0/type', 'childPosts/0/commentsCount', 'childPosts/0/likesCount', \
#        'childPosts/1/type', 'childPosts/1/commentsCount', 'childPosts/1/likesCount', \
#        'childPosts/2/type', 'childPosts/2/commentsCount', 'childPosts/2/likesCount', \
#         'childPosts/3/type', 'childPosts/3/commentsCount', 'childPosts/3/likesCount', \
#         'childPosts/4/type', 'childPosts/4/commentsCount', 'childPosts/4/likesCount', \
#         'childPosts/5/type', 'childPosts/5/commentsCount', 'childPosts/5/likesCount', \
#         'childPosts/6/type', 'childPosts/6/commentsCount', 'childPosts/6/likesCount', \
#         'childPosts/7/type', 'childPosts/7/commentsCount', 'childPosts/7/likesCount', \
#         'childPosts/8/type', 'childPosts/8/commentsCount', 'childPosts/8/likesCount', \
#         'childPosts/9/type', 'childPosts/9/commentsCount', 'childPosts/9/likesCount', ]
# # Reels Instagram
# col = ['id', 'commentsCount', 'isSponsored', 'timestamp', 'type', 'videoDuration', 'videoPlayCount', 'videoViewCount', 'likesCount', 'productType']
# # Brands Instagram
# col = ['id', 'username', 'biography', 'fullName', 'businessCategoryName', 'followersCount', 'highlightReelCount', 'igtvVideoCount', 'isBusinessAccount', \
#        'latestIgtvVideos/0/commentsCount', 'latestIgtvVideos/0/likesCount', 'latestIgtvVideos/0/timestamp', 'latestIgtvVideos/0/type', 'latestIgtvVideos/0/videoDuration', 'latestIgtvVideos/0/videoViewCount', \
#        'latestPosts/0/commentsCount', 'latestPosts/0/likesCount', 'latestPosts/0/timestamp', 'latestPosts/0/type', \
#         'latestPosts/1/commentsCount', 'latestPosts/1/likesCount', 'latestPosts/1/timestamp', 'latestPosts/1/type', \
#         'latestPosts/2/commentsCount', 'latestPosts/2/likesCount', 'latestPosts/2/timestamp', 'latestPosts/2/type']

# %%
df_selected = df[col]
df_selected
# Out:
#                     id  authorMeta/digg  authorMeta/fans authorMeta/region  \
# 0  7315376406597225729                0                4                VN
# 1  7315324674378943749                0                4                VN
# 2  7312729310983392514                0                4                VN
#
#    collectCount  commentCount  createTime             createTimeISO  \
# 0             0             0  1703243815  2023-12-22T11:16:55.000Z
# 1             0             0  1703231755  2023-12-22T07:55:55.000Z
# 2             0             0  1702645200  2023-12-15T13:00:00.000Z
#
#    diggCount  isPinned  isSlideshow  playCount  shareCount  \
# 0          0     False        False         79           0
# 1        277     False        False       4330           0
# 2          1     False        False         18           0
#
#    videoMeta/duration videoMeta/format
# 0                  56              mp4
# 1                  38              mp4
# ...

# %%
df_selected.to_excel('C:\\Users\\Nguyen_Thanh_Vinh\\Downloads\\Dataset\\Analysis data\\TikTok\\Khaar_TikTok.xlsx')
